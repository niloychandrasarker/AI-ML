# %% [markdown]
# # AI Programming With Python - Course Notes
#
# This notebook is a running course note for the full AI Programming With Python journey.
# It starts with Weak 01 and is designed to grow week by week as new topics are added.
# The answers below are split into one cell per problem.
# Use this notebook as a clean revision sheet, not just as raw code practice.
